# %%
import pandas as pd

# %%
df = pd.read_csv("E:\Backup\Academic\Project Work\Data\Age 21 to 25 years.csv")

# %%
df.head()
# Out:
#                  Age  Gender   Totalinternetusage  \
# 0  between 21 and 25  Female   4 hours to 8 hours
# 1  between 21 and 25  Female   4 hours to 8 hours
# 2  between 21 and 25  Female  8 hours to 12 hours
# 3  between 21 and 25  Female  8 hours to 12 hours
# 4  between 21 and 25  Female   4 hours to 8 hours
#
#                                          Leisuretime Pastmidnight  \
# 0                                7 hours to 14 hours   2 - 3 days
# 1                                 More than 24 hours   2 - 3 days
# 2                                7 hours to 14 hours   2 - 3 days
# 3  4 hours to 7 hours (one movie + mild usage of ...     Everyday
# 4                                7 hours to 14 hours     Everyday
#
#    Addictionrate Jobstatus  Qualityrate  Selfrate  \
# 0              3   Student          3.0       3.0
# 1              4   Student          2.0       1.0
# 2              4   Student          4.0       4.0
# 3              5   Student          3.0       4.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 231 non-null    object
#  1   Gender              231 non-null    object
#  2   Totalinternetusage  231 non-null    object
#  3   Leisuretime         231 non-null    object
#  4   Pastmidnight        231 non-null    object
#  5   Addictionrate       231 non-null    int64
#  6   Jobstatus           231 non-null    object
#  7   Qualityrate         225 non-null    float64
#  8   Selfrate            225 non-null    float64
#  9   Opportunities       225 non-null    object
#  10  Softcopy            225 non-null    object
#  11  Meetingduration     225 non-null    object
#  12  Interactions        225 non-null    object
#  13  Videoon             225 non-null    object
#  14  Distress            231 non-null    object
# ...

# %%
df.corr()
# Out:
#                Addictionrate  Qualityrate  Selfrate  Foodrate
# Addictionrate       1.000000    -0.032111 -0.036247  0.153844
# Qualityrate        -0.032111     1.000000  0.502812  0.037199
# Selfrate           -0.036247     0.502812  1.000000  0.067274
# Foodrate            0.153844     0.037199  0.067274  1.000000

# %%
df.describe(include="all")
# Out:
#                       Age  Gender  Totalinternetusage  \
# count                 231     231                 231
# unique                  1       2                   6
# top     between 21 and 25  Female  4 hours to 8 hours
# freq                  231     160                 111
# mean                  NaN     NaN                 NaN
# std                   NaN     NaN                 NaN
# min                   NaN     NaN                 NaN
# 25%                   NaN     NaN                 NaN
# 50%                   NaN     NaN                 NaN
# 75%                   NaN     NaN                 NaN
# max                   NaN     NaN                 NaN
#
#                                               Leisuretime Pastmidnight  \
# count                                                 231          231
# unique                                                  6            5
# top     4 hours to 7 hours (one movie + mild usage of ...     Everyday
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Totalinternetusage', 'Leisuretime', 'Pastmidnight',
#        'Addictionrate', 'Jobstatus', 'Qualityrate', 'Selfrate',
#        'Opportunities', 'Softcopy', 'Meetingduration', 'Interactions',
#        'Videoon', 'Distress', 'Mentalstress', 'Professionalaid', 'Exercise',
#        'Foodrate', 'Sleep', 'Cybercrime', 'Awayfrominternet', 'Basicneed'],
#       dtype='object')

# %%
df["Gender"].value_counts()
# Out:
# Female    160
# Male       71
# Name: Gender, dtype: int64

# %%
df['Jobstatus'].value_counts()
# Out:
# Student                           160
# Employed (full time)               31
# Student + Employed (part time)     27
# On a break                          7
# Self employed                       4
# Employed (part time)                2
# Name: Jobstatus, dtype: int64

# %%
#df1 = df.drop(columns= ['MostusedApps','Internetotheruse'],axis = 1)

# %%
#df1.head()

# %%
#df2 = pd.get_dummies(df1)
#df2

# %%
#df2.columns

# %%
#df3 = df2.drop(columns=['Age_more than 30 years old','Gender_Male','Totalinternetusage_More than 16 hours','Leisuretime_More than 24 hours','Pastmidnight_Never','Jobstatus_Others','Opportunities_No','Meetingduration_More than 2 hours','Interactions_No','Videoon_No','Distress_No','Mentalstress_No','Professionalaid_No','Exercise_No','Sleep_No','Cybercrime_No','Awayfrominternet_No','Basicneed_No'])

# %%
#df3.columns

# %%
#df3.tail()

# %%
#df3.to_csv("E:\Backup\Academic\Project Work\Data\Survey_cleaned.csv")

# %%
#df4 = pd.read_csv("E:\Backup\Academic\Project Work\Data\Improvement Parameters\Survey_data.csv")

# %%
#df4

# %%
#df4.describe()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['Totalinternetusage'].value_counts()
# Out:
# 4 hours to 8 hours      111
# 8 hours to 12 hours      59
# 2 hours to 4 hours       27
# 12 hours to 16 hours     15
# Less than 2 hours        10
# More than 16 hours        9
# Name: Totalinternetusage, dtype: int64

# %%
Totalinternetusage = ["Less than 14 hours","14 hours to 28 hours","28 hours to 56 hours","56 hours to 84 hours","84 hours to 112 hours"," More than 112 hours"]
Totalusage = [10,27,111,59,15,9]

# %%
df['Leisuretime'].value_counts()
# Out:
# 4 hours to 7 hours (one movie + mild usage of social media and other apps)    78
# 7 hours to 14 hours                                                           56
# More than 24 hours                                                            41
# 14 hours to 24 hours                                                          31
# Less than 4 hours (approx. one movie per week and no other business)          20
# I strictly use internet for my work related activities                         5
# Name: Leisuretime, dtype: int64

# %%
Leisuretime = ["No Leisure Use","Less than 4 hours","4 hours to 7 hours","7 hours to 14 hours","14 hours to 24 hours","More than 24 hours"]
Leisureusage = [5,20,78,56,31,41]

# %%
plt.figure(figsize = (30,20))
plt.barh(Totalinternetusage,width = Totalusage,label = "Total Internet Usage ")
plt.barh(Leisuretime, width = Leisureusage, label = "Leisure time Internet Usage")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 24)
plt.tick_params(axis = 'y',labelsize = 24)
plt.xlabel("Number of people", fontsize = 24)
plt.title("Internet Usage - Total Usage versus Leisure time (weekly)",fontsize = 28)
plt.legend(fontsize = 20)
plt.grid()

# %%
df['Pastmidnight'].value_counts()
# Out:
# Everyday      74
# 2 - 3 days    63
# 4 - 6 days    43
# Never         33
# 1 day         18
# Name: Pastmidnight, dtype: int64

# %%
Pastmidnight = ["Never","One day","Two or Three days","Four to Six days","Everyday"]
Pastmid = [33,18,43,63,74]

# %%
plt.figure(figsize = (30,10))
plt.barh(Pastmidnight,width = Pastmid,label = "Internet Usage past midnight")
plt.barh(Leisuretime, width = Leisureusage, label = "Leisure time Internet Usage")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Internet Usage - Past Midnight versus Leisure time (weekly)",fontsize = 28)
plt.legend(fontsize = 20)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(Pastmidnight,width = Pastmid,label = "Internet Usage past midnight")
plt.barh(Totalinternetusage,width = Totalusage,label = "Total Internet Usage ")
plt.barh(Leisuretime, width = Leisureusage, label = "Leisure time Internet Usage")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Internet Usage and Past Midnight Internet Usage",fontsize = 28)
plt.legend(fontsize = 20)
plt.grid()

# %%
Corrgraph(Leisureusage,Totalusage,"Leisure time Internet Usage","Total Internet Usage ","Internet Usage - Total Usage versus Leisure time (weekly)")
np.corrcoef(Leisureusage,Totalusage)
scipy.stats.spearmanr(Leisureusage,Totalusage)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# SpearmanrResult(correlation=0.6, pvalue=0.20799999999999982)

# %%
df['Qualityrate'].value_counts()
# Out:
# 3.0    93
# 4.0    64
# 2.0    34
# 5.0    18
# 1.0    16
# Name: Qualityrate, dtype: int64

# %%
Quality = ["Worst Quality","Could be better","Moderate Quality","Good quality","Excellent Quality"]
Qualityrate = [16,34,93,64,18]

# %%
df['Selfrate'].value_counts()
# Out:
# 3.0    87
# 4.0    59
# 2.0    42
# 5.0    23
# 1.0    14
# Name: Selfrate, dtype: int64

# %%
Self = ["Worst Output","Could have done better","Moderate Output","Good Output","Excellent Output"]
Selfrate = [14,42,87,59,23]

# %%
plt.figure(figsize = (30,10))
plt.barh(Quality,width = Qualityrate ,label = "Quality provided by Workplace")
plt.barh(Self,width = Selfrate,label = "Quality of work from the subject")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Quality of work - Workplace quality versus Subject's Output Quality",fontsize = 28)
plt.legend(fontsize = 20)
plt.grid()

# %%
import numpy as np
Corr = np.corrcoef(Qualityrate,Selfrate)
Corr
# Out:
# array([[1.        , 0.98746394],
#        [0.98746394, 1.        ]])

# %%
import scipy.stats
scipy.stats.spearmanr(Qualityrate,Selfrate)
# Out:
# SpearmanrResult(correlation=0.9999999999999999, pvalue=1.4042654220543672e-24)

# %%
def Corrgraph(x,y,xlabel,ylabel,title):
    plt.figure(figsize=(5,5))
    sns.regplot(x,y)
    plt.ylim(0,)
    #plt.xlim(-1,1)
    plt.title(title)
    plt.xlabel(xlabel,fontsize = 12)
    plt.ylabel(ylabel,fontsize = 12)
    plt.grid()

# %%
import seaborn as sns
Corrgraph(Qualityrate,Selfrate,"Quality provided by Workplace","Quality of work from the subject's side ","Quality of work - Workplace quality versus Subject's Output Quality")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['Opportunities'].value_counts()
# Out:
# Yes, Absolutely                                                                   95
# No                                                                                63
# There were opportunities but I didn't take them                                   58
# There were no opportunities and the worst - available opportunities diminished     9
# Name: Opportunities, dtype: int64

# %%
Oppor = ["The Opportunities diminished","There were no Opportunities","There were Opportunities but minimum Utilization","There were Opportunities and Maximum Utilization"]
Oppo = [9,63,58,95]

# %%
plt.figure(figsize = (30,20))
plt.barh(Quality,width = Qualityrate ,label = "Quality provided by Workplace")
#plt.barh(Self,width = Selfrate,label = "Quality of work from the subject")
plt.barh(Oppor,Oppo, label = "Opportunities for growth in the respective field")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 24)
plt.tick_params(axis = 'y',labelsize = 24)
plt.xlabel("Number of people", fontsize = 22)
plt.title("Quality of work and workplace versus Opportunities for growth",fontsize = 30)
plt.legend(fontsize = 22,loc = 0)
plt.grid()

# %%
df['Addictionrate'].value_counts()
# Out:
# 3    91
# 4    73
# 2    29
# 5    22
# 1    16
# Name: Addictionrate, dtype: int64

# %%
Addrate = ["Experimental Use","Recreational Use","Circumstantial Use","Intensified Use","Compulsive Use"]
Addiction = [16,29,91,73,22]

# %%
plt.figure(figsize = (30,10))
#plt.barh(Totalinternetusage,width = Totalusage,label = "Total Internet Usage ")
plt.barh(Pastmidnight,width = Pastmid,label = "Internet Usage past midnight")
plt.barh(Addrate,Addiction, label = "Addiction Rate")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 24)
plt.tick_params(axis = 'y',labelsize = 24)
plt.xlabel("Number of people", fontsize = 24)
plt.title("Addiction Rate and Past Midnight Internet Usage",fontsize = 28)
plt.legend(fontsize = 22)
plt.grid()

# %%
Corrgraph(Pastmid,Addiction,"Interent Usage after Midnight","Internet Addiction Rate","Internet Usage after Midnight versus Addiciton Rate")
np.corrcoef(Pastmid,Addiction)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# array([[1.        , 0.17076137],
#        [0.17076137, 1.        ]])

# %%
df['Interactions'].value_counts()
# Out:
# Depending on the audience    92
# No                           77
# Yes                          56
# Name: Interactions, dtype: int64

# %%
m_inter = ["No Participation","Depending on the Audience","Highly Interative"]
m_interations = [77,92,56]
m_video = ["Video is never turned ON","Depending on the Audience","Always Video ON"]
m_videoOn = [136,74,15]

# %%
df['Videoon'].value_counts()
# Out:
# No                           136
# Depending on the audience     74
# Yes                           15
# Name: Videoon, dtype: int64

# %%
df['Interactions'].value_counts().std()
# Out:
# 18.083141320025124

# %%
df['Interactions'].value_counts().mean()
# Out:
# 75.0

# %%
df['Videoon'].value_counts().std()
# Out:
# 60.50619802962338

# %%
df['Videoon'].value_counts().mean()
# Out:
# 75.0

# %%
plt.figure(figsize = (30,10))
plt.barh(m_inter,m_interations,label = "Interaction during video meetings")
plt.barh(m_video,m_videoOn,label = "Keeping the Video ON during meetings")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Interaction versus Keeping video ON during meetings",fontsize = 28)
plt.legend(fontsize = 20)
plt.grid()

# %%
Corrgraph(m_interations,m_videoOn,"Interaction during video meetings","Keeping the Video ON during meetings","Interaction versus Keeping video ON during meetings")
np.corrcoef(m_interations,m_videoOn)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# array([[1.        , 0.56893888],
#        [0.56893888, 1.        ]])

# %%
plt.figure(figsize = (30,10))
plt.barh(m_inter,m_interations,label = "Interaction during video meetings")
plt.barh(m_video,m_videoOn,label = "Keeping the Video ON during meetings")
plt.barh(Quality,width = Qualityrate ,label = "Quality provided by Workplace")
plt.barh(Self,width = Selfrate,label = "Quality of work from the subject")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Interaction and keeping video ON during meetings versus Quality of workplace and work",fontsize = 28)
plt.legend(fontsize = 20)
plt.grid()

# %%
df['Meetingduration'].value_counts()
# Out:
# More than 2 hours               122
# 1 hour to 2 hours                75
# 1/2 hour to 1 hour               22
# Less than half an hour or so      6
# Name: Meetingduration, dtype: int64

# %%
Duration = ["Less than half an hour","Half an hour to one hour","One hour to two hours","More than 2 hours"]
M_dura = [6,22,75,122]

# %%
plt.figure(figsize = (30,10))
plt.barh(Duration,M_dura,label = "Meeting Duration")
plt.barh(Quality,width = Qualityrate ,label = "Quality provided by Workplace")
plt.barh(Self,width = Selfrate,label = "Quality of work from the subject")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Quality of workplace and work versus Meeting Duration",fontsize = 28)
plt.legend(fontsize = 20)
plt.grid()

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Totalinternetusage', 'Leisuretime', 'Pastmidnight',
#        'Addictionrate', 'Jobstatus', 'Qualityrate', 'Selfrate',
#        'Opportunities', 'Softcopy', 'Meetingduration', 'Interactions',
#        'Videoon', 'Distress', 'Mentalstress', 'Professionalaid', 'Exercise',
#        'Foodrate', 'Sleep', 'Cybercrime', 'Awayfrominternet', 'Basicneed'],
#       dtype='object')

# %%
df[ 'Awayfrominternet'].value_counts()
# Out:
# No     168
# Yes     63
# Name: Awayfrominternet, dtype: int64

# %%
InternetAway = ["Cannot stay away from Internet","Can stay away from Internet"]
Internaway = [168,63]

# %%
df['Basicneed'].value_counts()
# Out:
# Yes         171
# Somewhat     53
# No            7
# Name: Basicneed, dtype: int64

# %%
Basicneed = ["Internet is NOT a Basic Need","Internet is somewhat Basic","Internet is a basic need"]
Basic = [7,53,171]
Basic1 = [171,60]

# %%
print(np.corrcoef(Basic1,Internaway))
print(scipy.stats.spearmanr(Basic1,Internaway))
Corrgraph(Basic1,Internaway,"Internet is a basic Need","Cannot stay away from Internet","Internet is a basic need versus Cannot stay away from Internet")
# Out:
# [[1. 1.]
#  [1. 1.]]
# SpearmanrResult(correlation=0.9999999999999999, pvalue=nan)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (30,20))
plt.barh(Totalinternetusage,width = Totalusage,label = "Total Internet Usage ")
plt.barh(Pastmidnight,width = Pastmid,label = "Internet Usage past midnight")
plt.barh(Addrate,Addiction, label = "Addiction Rate")
plt.barh(InternetAway,Internaway, label = "Keeping Internet Away for Prolonged period")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Internet Usage, Addiction Rate and Willingness to keep Internet away",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(Addrate,Addiction, label = "Addiction Rate")
plt.barh(InternetAway,Internaway, label = "Keeping Internet Away for Prolonged period")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Addiction Rate and Willingness to keep Internet away",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(Addrate,Addiction, label = "Addiction Rate")
plt.barh(InternetAway,Internaway, label = "Keeping Internet Away for Prolonged period")
plt.barh(Basicneed,Basic, label = "Whether Internet is a Basic need?")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Addiction Rate,Willingness to keep Internet away and whether Internet is a basic need?",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(InternetAway,Internaway, label = "Keeping Internet Away for Prolonged period")
plt.barh(Basicneed,Basic, label = "Whether Internet is a Basic need?")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Willingness to keep Internet away and whether Internet is a basic need?",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
df['Distress'].value_counts()
# Out:
# No     174
# Yes     57
# Name: Distress, dtype: int64

# %%
Distress = ["No Physical Discomforts experienced","Experienced Physical Discomforts"]
Distr = [174,57]

# %%
df['Mentalstress'].value_counts()
# Out:
# Yes    169
# No      62
# Name: Mentalstress, dtype: int64

# %%
Mental = ["No Mental Stress Experienced","Experienced Mental trauma"]
Mentalstress = [62,169]

# %%
df['Professionalaid'].value_counts()
# Out:
# No     184
# Yes     47
# Name: Professionalaid, dtype: int64

# %%
Aid = ["Did not seek any aid","Sought Medical aid"]
Profaid = [184,47]

# %%
plt.figure(figsize = (30,10))
plt.barh(Distress,Distr,label = "Physical Distress during Lockdowns")
plt.barh(Mental,Mentalstress,label = "Mental Distress during lockdowns")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Physical Distress and Mental Distress Experienced during Lockdowns",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(Distress,Distr,label = "Physical Distress during Lockdowns")
plt.barh(Totalinternetusage,width = Totalusage,label = "Total Internet Usage ")
plt.barh(Pastmidnight,width = Pastmid,label = "Internet Usage past midnight")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Physical Distress and Internet Usage during Lockdowns",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(Mental,Mentalstress,label = "Mental Distress during lockdowns")
plt.barh(Totalinternetusage,width = Totalusage,label = "Total Internet Usage ")
plt.barh(Pastmidnight,width = Pastmid,label = "Internet Usage past midnight")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Mental Distress Experienced and Internet Usage during Lockdowns",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(Mental,Mentalstress,label = "Mental Distress during lockdowns")
plt.barh(Aid,Profaid,label = "Professional Aid Sought")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Mental Distress Experienced and Professional aid ",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Totalinternetusage', 'Leisuretime', 'Pastmidnight',
#        'Addictionrate', 'Jobstatus', 'Qualityrate', 'Selfrate',
#        'Opportunities', 'Softcopy', 'Meetingduration', 'Interactions',
#        'Videoon', 'Distress', 'Mentalstress', 'Professionalaid', 'Exercise',
#        'Foodrate', 'Sleep', 'Cybercrime', 'Awayfrominternet', 'Basicneed'],
#       dtype='object')

# %%
df['Exercise'].value_counts()
# Out:
# Yes          101
# Sometimes     96
# No            34
# Name: Exercise, dtype: int64

# %%
Exercise = ["Did not Exercise","Irregular","Regular"]
Exe = [34,96,101]

# %%
df['Foodrate'].value_counts()
# Out:
# 3    93
# 4    66
# 2    28
# 5    28
# 1    16
# Name: Foodrate, dtype: int64

# %%
Food = ["Consumption Decreased sharply","Consumption Decreased slightly","No change","Consumption increased slightly","Consumption increased sharply"]
Foodrate = [16,28,93,66,28]

# %%
df["Sleep"].value_counts()
# Out:
# Yes    136
# No      95
# Name: Sleep, dtype: int64

# %%
Sleep = ["No Sleep disruptions","Frequent Sleep Disruptions"]
Sleeprate = [95,136]

# %%
plt.figure(figsize = (30,10))
plt.barh(Exercise,Exe, label = "Frequency of Exercising  during Lockdowns")
plt.barh(Distress,Distr,label = "Physical Distress during Lockdowns")
plt.barh(Mental,Mentalstress,label = "Mental Distress during lockdowns")
plt.barh(Totalinternetusage,width = Totalusage,label = "Total Internet Usage ")
plt.barh(Leisuretime, width = Leisureusage, label = "Leisure time Internet Usage")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Exercise frequency,Mental & Physical Distress Experienced and Internet Usage during Lockdowns",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(Exercise,Exe, label = "Frequency of Exercising  during Lockdowns")
plt.barh(Distress,Distr,label = "Physical Distress during Lockdowns")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Exercise frequency and Physical Distress during Lockdowns",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(Exercise,Exe, label = "Frequency of Exercising  during Lockdowns")
plt.barh(Mental,Mentalstress,label = "Mental Distress during lockdowns")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Exercise frequency and Mental Distress during Lockdowns",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(Exercise,Exe, label = "Frequency of Exercising  during Lockdowns")
plt.barh(Leisuretime, width = Leisureusage, label = "Leisure time Internet Usage")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Exercise frequency and Leisure time Internet Use during Lockdowns",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(Food,Foodrate, label = "Food Consumption Rate")
plt.barh(Leisuretime, width = Leisureusage, label = "Leisure time Internet Usage")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Food Consumption Rate and Leisure time Internet Use during Lockdowns",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(Food,Foodrate, label = "Food Consumption Rate")
plt.barh(Pastmidnight,width = Pastmid,label = "Internet Usage past midnight")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Food Consumption Rate and Past midnight Internet Use during Lockdowns",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(Food,Foodrate, label = "Food Consumption Rate")
plt.barh(Sleep,Sleeprate,label = "Sleep Pattern during the lockdowns")
plt.barh(Pastmidnight,Pastmid,label = "Internet Usage past midnight")
plt.barh(Leisuretime,Leisureusage, label = "Leisure time Internet Usage")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Food Consumption Rate, Sleep Patterns and Past midnight Internet Use during Lockdowns",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()

# %%
plt.figure(figsize = (40,10))
plt.barh(Distress,Distr,label = "Physical Distress during Lockdowns")
plt.barh(Mental,Mentalstress,label = "Mental Distress during lockdowns")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 24)
plt.tick_params(axis = 'y',labelsize = 24)
plt.xlabel("Number of people", fontsize = 24)
plt.title("Mental & Physical Distress Experienced during Lockdowns",fontsize = 28)
plt.legend(fontsize = 24,loc = 0)
plt.grid()

# %%
plt.plot(Distr,Distress)
plt.plot(Mentalstress,Mental)
plt.tick_params(axis = 'x',rotation = 0,labelsize = 12)

# %%
from scipy.interpolate import make_interp_spline
plt.figure(figsize = (30,10))
plt.subplot(121)
plt.plot(Leisuretime,Leisureusage,'--b',label ="Leisure time ")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,6,1))
X_Y_Spline = make_interp_spline(rnge,Leisureusage)
X_ = np.linspace(rnge.min(), rnge.max(),150)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Leisure Time",linewidth = 3)
plt.title("Internet Usage time for Leisure (Weekly)",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()
plt.subplot(122)
plt.plot(Totalinternetusage,Totalusage,label = "Total Internet Usage ")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,6,1))
X_Y_Spline = make_interp_spline(rnge,Totalusage)
X_ = np.linspace(rnge.min(), rnge.max(),500)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Internet Usage Time",linewidth = 3)
plt.title("Total Internet Usage time(Weekly)",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.subplot(131)
plt.plot(Leisuretime,Leisureusage,'--b',label ="Leisure time ")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,6,1))
X_Y_Spline = make_interp_spline(rnge,Leisureusage)
X_ = np.linspace(rnge.min(), rnge.max(),150)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Leisure Time",linewidth = 3)
plt.title("Internet Usage time for Leisure (Weekly)",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()
plt.subplot(132)
plt.plot(Totalinternetusage,Totalusage,label = "Total Internet Usage ")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,6,1))
X_Y_Spline = make_interp_spline(rnge,Totalusage)
X_ = np.linspace(rnge.min(), rnge.max(),500)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Internet Usage Time",linewidth = 3)
plt.title("Total Internet Usage time(Weekly)",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()
plt.subplot(133)
plt.plot(Pastmidnight,Pastmid,label = "Internet Usage after Midnight ")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,5,1))
X_Y_Spline = make_interp_spline(rnge,Pastmid)
X_ = np.linspace(rnge.min(), rnge.max(),500)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Internet Usage after Midnight",linewidth = 3)
plt.title("Frequency of Internet Usage after Midnight",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.subplot(131)
plt.plot(Leisuretime,Leisureusage,'--b',label ="Leisure time ")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,6,1))
X_Y_Spline = make_interp_spline(rnge,Leisureusage)
X_ = np.linspace(rnge.min(), rnge.max(),150)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Leisure Time",linewidth = 3)
plt.title("Internet Usage time for Leisure (Weekly)",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()
plt.subplot(132)
plt.plot(Pastmidnight,Pastmid,label = "Internet Usage after Midnight ")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,5,1))
X_Y_Spline = make_interp_spline(rnge,Pastmid)
X_ = np.linspace(rnge.min(), rnge.max(),500)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Internet Usage after Midnight",linewidth = 3)
plt.title("Frequency of Internet Usage after Midnight",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()
plt.subplot(133)
plt.plot(Food,Foodrate, label = "Food Consumption Rate")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,5,1))
X_Y_Spline = make_interp_spline(rnge,Foodrate)
X_ = np.linspace(rnge.min(), rnge.max(),500)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Food Consumtion Rating",linewidth = 3)
plt.title("Food Consumption Rate during Lockdowns",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.subplot(121)
plt.plot(Pastmidnight,Pastmid,label = "Internet Usage after Midnight ")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,5,1))
X_Y_Spline = make_interp_spline(rnge,Pastmid)
X_ = np.linspace(rnge.min(), rnge.max(),500)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Internet Usage after Midnight",linewidth = 3)
plt.title("Frequency of Internet Usage after Midnight",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()
plt.subplot(122)
plt.plot(Food,Foodrate, label = "Food Consumption Rate")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,5,1))
X_Y_Spline = make_interp_spline(rnge,Foodrate)
X_ = np.linspace(rnge.min(), rnge.max(),500)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Food Consumtion Rating",linewidth = 3)
plt.title("Food Consumption Rate during Lockdowns",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.subplot(131)
plt.plot(Leisuretime,Leisureusage,'--b',label ="Leisure time ")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,6,1))
X_Y_Spline = make_interp_spline(rnge,Leisureusage)
X_ = np.linspace(rnge.min(), rnge.max(),150)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Leisure Time",linewidth = 3)
plt.title("Internet Usage time for Leisure (Weekly)",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()
plt.subplot(132)
plt.plot(Pastmidnight,Pastmid,label = "Internet Usage after Midnight ")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,5,1))
X_Y_Spline = make_interp_spline(rnge,Pastmid)
X_ = np.linspace(rnge.min(), rnge.max(),500)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Internet Usage after Midnight",linewidth = 3)
plt.title("Frequency of Internet Usage after Midnight",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()
plt.subplot(133)
plt.plot(Addrate,Addiction, label = "Addiction Rate")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,5,1))
X_Y_Spline = make_interp_spline(rnge,Addiction)
X_ = np.linspace(rnge.min(), rnge.max(),500)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Addiction Self - Rating",linewidth = 3)
plt.title("Internet Addiction Self - Rate",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.subplot(121)
plt.plot(Quality,Qualityrate ,label = "Quality provided by Workplace")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,5,1))
X_Y_Spline = make_interp_spline(rnge,Qualityrate)
X_ = np.linspace(rnge.min(), rnge.max(),500)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Quality of Workplace Internet Infrastructure",linewidth = 3)
plt.title("Quality of Workplace Internet Infrastructure",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()
plt.subplot(122)
plt.plot(Self,Selfrate,label = "Quality of work from the subject")
plt.tick_params(axis = 'x',rotation = 30,labelsize = 14)
plt.tick_params(axis = 'y',rotation = 0,labelsize = 16)
rnge = np.array(range(0,5,1))
X_Y_Spline = make_interp_spline(rnge,Selfrate)
X_ = np.linspace(rnge.min(), rnge.max(),500)
Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_,'r', label = "Smoothened Quality of work by the Subject",linewidth = 3)
plt.title("Quality of work from the Subject",fontsize = 22)
plt.ylabel("Number of people",fontsize = 16)
plt.legend(loc = 0,fontsize = 18)
plt.grid()

# %%
plt.figure(figsize = (30,10))
plt.barh(Sleep,Sleeprate,label = "Sleep Pattern during the lockdowns")
plt.barh(Pastmidnight,Pastmid,label = "Internet Usage past midnight")
plt.tick_params(axis = 'x',rotation = 0,labelsize = 20)
plt.tick_params(axis = 'y',labelsize = 20)
plt.xlabel("Number of people", fontsize = 20)
plt.title("Sleep Patterns and Past midnight Internet Use during Lockdowns",fontsize = 28)
plt.legend(fontsize = 20,loc = 0)
plt.grid()
